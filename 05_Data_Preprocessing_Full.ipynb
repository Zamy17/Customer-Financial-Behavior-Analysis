# %% [markdown]
# # 05 - Data Preprocessing
#
# **Customer Financial Behavior Analysis for Banking Business Intelligence**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

df = pd.read_csv("customer_features.csv")
df.head()
# Out:
#   AccountID  CustomerAge CustomerOccupation  TransactionAmount  \
# 0   AC00001         25.0            Student         130.380000
# 1   AC00002         71.0            Retired         293.744286
# 2   AC00003         69.0             Doctor         253.268000
# 3   AC00004         64.0            Retired         264.807500
# 4   AC00005         52.0           Engineer         347.974444
#
#    AccountBalance  LoginAttempts  TransactionDuration  TransactionHour  \
# 0     2915.160000       1.000000           107.500000              8.0
# 1     4480.421429       1.142857           109.857143              8.0
# 2     7329.568000       1.000000            49.200000              8.0
# 3     2712.905000       1.000000           115.000000              8.0
# 4     4457.837778       1.000000           145.111111              8.0
#
#    DaysSincePreviousTransaction  TotalTransactionPerAccount  \
# 0                    385.000000                           2
# ...

# %%
print(df.shape)
df.info()
# Out:
# (495, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   AccountID                     495 non-null    object
#  1   CustomerAge                   495 non-null    float64
#  2   CustomerOccupation            495 non-null    object
#  3   TransactionAmount             495 non-null    float64
#  4   AccountBalance                495 non-null    float64
#  5   LoginAttempts                 495 non-null    float64
#  6   TransactionDuration           495 non-null    float64
#  7   TransactionHour               495 non-null    float64
#  8   DaysSincePreviousTransaction  495 non-null    float64
#  9   TotalTransactionPerAccount    495 non-null    int64
#  10  AverageTransaction            495 non-null    float64
#  11  AverageBalance                495 non-null    float64
# ...

# %%
for col in df.columns:
    if df[col].dtype=="object":
        df[col]=df[col].fillna(df[col].mode()[0])
    else:
        df[col]=df[col].fillna(df[col].median())

df.isnull().sum()
# Out:
# AccountID                       0
# CustomerAge                     0
# CustomerOccupation              0
# TransactionAmount               0
# AccountBalance                  0
# LoginAttempts                   0
# TransactionDuration             0
# TransactionHour                 0
# DaysSincePreviousTransaction    0
# TotalTransactionPerAccount      0
# AverageTransaction              0
# AverageBalance                  0
# DebitCount                      0
# CreditCount                     0
# FavoriteChannel                 0
# FavoriteMerchant                0
# DebitRatio                      0
# CreditRatio                     0
# dtype: int64

# %%
categorical=df.select_dtypes(include="object").columns

encoders={}
for col in categorical:
    le=LabelEncoder()
    df[col]=le.fit_transform(df[col].astype(str))
    encoders[col]=le

print(categorical.tolist())
# Out:
# ['AccountID', 'CustomerOccupation', 'FavoriteChannel', 'FavoriteMerchant']

# %%
features=[
"CustomerAge","TransactionAmount","AccountBalance",
"LoginAttempts","TransactionDuration","TransactionHour",
"DaysSincePreviousTransaction","TotalTransactionPerAccount",
"AverageTransaction","AverageBalance","DebitCount",
"CreditCount","DebitRatio","CreditRatio",
"FavoriteChannel","FavoriteMerchant"
]

X=df[features]
X.head()
# Out:
#    CustomerAge  TransactionAmount  AccountBalance  LoginAttempts  \
# 0         25.0         130.380000     2915.160000       1.000000
# 1         71.0         293.744286     4480.421429       1.142857
# 2         69.0         253.268000     7329.568000       1.000000
# 3         64.0         264.807500     2712.905000       1.000000
# 4         52.0         347.974444     4457.837778       1.000000
#
#    TransactionDuration  TransactionHour  DaysSincePreviousTransaction  \
# 0           107.500000              8.0                    385.000000
# 1           109.857143              8.0                    509.571429
# 2            49.200000              8.0                    575.800000
# 3           115.000000              8.0                    427.875000
# 4           145.111111              8.0                    488.777778
#
#    TotalTransactionPerAccount  AverageTransaction  AverageBalance  DebitCount  \
# ...

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

X_scaled=pd.DataFrame(X_scaled,columns=features)
X_scaled.head()
# Out:
#    CustomerAge  TransactionAmount  AccountBalance  LoginAttempts  \
# 0    -1.146873          -1.165862       -1.067993      -0.387886
# 1     1.546156           0.414515       -0.319887       0.091887
# 2     1.429068           0.022949        1.041842      -0.387886
# 3     1.136347           0.134582       -1.164659      -0.387886
# 4     0.433818           0.939134       -0.330681      -0.387886
#
#    TransactionDuration  TransactionHour  DaysSincePreviousTransaction  \
# 0            -0.325044              0.0                     -1.790369
# 1            -0.261130              0.0                      0.340547
# 2            -1.905859              0.0                      1.473452
# 3            -0.121680              0.0                     -1.056950
# 4             0.694788              0.0                     -0.015149
#
#    TotalTransactionPerAccount  AverageTransaction  AverageBalance  DebitCount  \
# ...

# %%
X_scaled.to_csv("customer_preprocessed.csv",index=False)
print("Saved customer_preprocessed.csv")
# Out:
# Saved customer_preprocessed.csv

# %% [markdown]
# Dataset hasil preprocessing siap digunakan pada tahap **K-Means Clustering**.
